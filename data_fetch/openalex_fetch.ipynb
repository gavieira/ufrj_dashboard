# %% [markdown]
# # Script to get all results from OpenAlex's API

# %% [markdown]
# We'll create a script to download all works from a given institution (UFRJ) in OpenAlex using its 'works' API.
#
# The 'cursor paging' feature will be used to do so. More on that [here](https://github.com/ourresearch/openalex-api-tutorials/blob/main/notebooks/getting-started/paging.ipynb).
#
# Note that OpenAlex has quite a few API's, each dealing with different types of data:
#
# ![OpenAlex's entities](https://docs.openalex.org/~gitbook/image?url=https%3A%2F%2F334408415-files.gitbook.io%2F%7E%2Ffiles%2Fv0%2Fb%2Fgitbook-x-prod.appspot.com%2Fo%2Fspaces%252FpHVuV3Ib5KXeBKft4Kcl%252Fuploads%252Fgit-blob-f2467ba820f38bcd9dc58a791415c8bd1fbcafec%252Fentities.png%3Falt%3Dmedia&width=768&dpr=1&quality=100&sign=60a05a56&sv=2)

# %%
import requests #We'll need the requests library to make API requests

# %%
#Let's see some information about the institution of interest (UFRJ) using the API
#We'll use its ROR identifier to do so (https://ror.org/03490as77)

ufrj_info = requests.get('https://api.openalex.org/institutions?filter=ror:03490as77').json()
ufrj_info['results']
# Out:
# [{'id': 'https://openalex.org/I122140584',
#   'ror': 'https://ror.org/03490as77',
#   'display_name': 'Universidade Federal do Rio de Janeiro',
#   'country_code': 'BR',
#   'type': 'education',
#   'type_id': 'https://openalex.org/institution-types/education',
#   'lineage': ['https://openalex.org/I122140584'],
#   'homepage_url': 'https://ufrj.br',
#   'image_url': 'https://commons.wikimedia.org/w/index.php?title=Special:Redirect/file/Minerva%20UFRJ.jpg',
#   'image_thumbnail_url': 'https://commons.wikimedia.org/w/index.php?title=Special:Redirect/file/Minerva%20UFRJ.jpg&width=300',
#   'display_name_acronyms': ['UFRJ'],
#   'display_name_alternatives': ['Federal University of Rio de Janeiro'],
#   'repositories': [],
#   'works_count': 144605,
#   'cited_by_count': 2243183,
#   'summary_stats': {'2yr_mean_citedness': 1.8833812260536398,
#    'h_index': 356,
#    'i10_index': 45261},
#   'ids': {'openalex': 'https://openalex.org/I122140584',
#    'ror': 'https://ror.org/03490as77',
#    'mag': '122140584',
#    'grid': 'grid.8536.8',
#    'wikipedia': 'https://en.wikipedia.org/wiki/Federal%20University%20of%20Rio%20de%20Janeiro',
#    'wikidata': 'https://www.wikidata.org/wiki/Q586904'},
#   'geo': {'city': 'Rio de Janeiro',
#    'geonames_city_id': '3451190',
#    'region': None,
#    'country_code': 'BR',
#    'country': 'Brazil',
#    'latitude': -22.90642,
#    'longitude': -43.18223},
#   'international': {'display_name': {'ar': 'الجامعة الاتحادية لريو دي جانيرو',
#     'ast': 'Universidá Federal de Rio de Janeiro',
#     'az': 'Rio-de-Janeyro Federal Universiteti',
#     'ba': 'Рио-де-Жанейро федераль университеты',
#     'be': 'Федэральны ўніверсітэт Рыа-дэ-Жанэйра',
#     'be-tarask': 'Фэдэральны ўнівэрсытэт Рыю-дэ-Жанэйру',
#     'bs': 'Federalni Univerzitet Rio de Janeiro',
#     'ca': 'Universitat Federal de Rio de Janeiro',
#     'ceb': 'Federal University of Rio de Janeiro',
#     'cs': 'Federální univerzita v Rio de Janeiru',
#     'cy': 'Universidad Federal de Río de Janeiro',
#     'da': 'Universidade Federal do Rio de Janeiro',
#     'de': 'Universidade Federal do Rio de Janeiro',
#     'de-ch': 'Universidade Federal do Rio de Janeiro',
#     'el': 'Ομοσπονδιακό πανεπιστήμιο του Ρίο ντε Τζανέιρο',
#     'en': 'Federal University of Rio de Janeiro',
#     'en-ca': 'Federal University of Rio de Janeiro',
#     'en-gb': 'Federal University of Rio de Janeiro',
#     'eo': 'Federala Universitato de Rio de Janeiro',
#     'es': 'Universidad Federal de Río de Janeiro',
#     'eu': 'Rio de Janeiroko Unibertsitate Federala',
#     'fa': 'دانشگاه فدرال ریودوژانیرو',
#     'fi': 'Rio de Janeiron liittovaltionyliopisto',
#     'fr': 'université fédérale de Rio de Janeiro',
#     'gl': 'Universidade Federal do Río de Xaneiro',
#     'gsw': 'Universidade Federal do Rio de Janeiro',
#     'he': "האוניברסיטה הפדרלית של ריו דה ז'ניירו",
#     'hi': 'फ़ेडरल विश्वविद्यालय',
#     'hu': 'Universidade Federal do Rio de Janeiro',
#     'hy': 'Ռիո դե Ժանեյրոյի դաշնային համալսարան',
#     'id': 'Universitas Federal Rio de Janeiro',
#     'it': 'Università Federale di Rio de Janeiro',
#     'ja': 'リオデジャネイロ連邦大学',
#     'ka': 'რიო-დე-ჟანეიროს ფედერალური უნივერსიტეტი',
#     'ko': '리우데자네이루 연방 대학교',
#     'la': 'Universitas Foederalis Fluminis Ianuarii',
#     'ml': 'ഫെഡറൽ യൂണിവേഴ്സിറ്റി ഓഫ് റിയോ ഡി ജനീറോ',
#     'nb': 'Universidade Federal do Rio de Janeiro',
#     'nl': 'Federale Universiteit van Rio de Janeiro',
#     'pa': 'ਫੈਡਰਲ ਯੂਨੀਵਰਸਿਟੀ',
#     'pl': 'Universidade Federal do Rio de Janeiro',
#     'pt': 'Universidade Federal do Rio de Janeiro',
#     'pt-br': 'Universidade Federal do Rio de Janeiro',
#     'ru': 'Федеральный университет Рио-де-Жанейро',
#     'sl': 'Zvezna univerza v Rio de Janeiru',
#     'sr': 'Федерални Универзитет Рио де Жанеира',
#     'sv': 'Universidade Federal do Rio de Janeiro',
#     'tl': 'Pamantasang Federal ng Rio de Janeiro',
#     'tr': 'Rio de Janeiro Federal Üniversitesi',
#     'uk': 'Федеральний університет Ріо-де-Жанейро',
#     'vi': 'Đại học Liên bang Rio de Janeiro',
#     'war': 'Unibersidad Federal han Rio de Janeiro',
#     'yue': '里約熱內盧聯邦大學',
#     'zh': '里约热内卢联邦大学',
#     'zh-hant': '里約熱內盧聯邦大學'}},
#   'associated_institutions': [{'id': 'https://openalex.org/I4210126836',
#     'ror': 'https://ror.org/036f2ks50',
#     'display_name': 'Ciências e Cognição',
#     'country_code': 'BR',
#     'type': 'other',
#     'relationship': 'child'},
#    {'id': 'https://openalex.org/I4210089367',
#     'ror': 'https://ror.org/005cybj21',
#     'display_name': 'Valongo Observatory',
#     'country_code': 'BR',
#     'type': 'facility',
#     'relationship': 'child'},
#    {'id': 'https://openalex.org/I4210138087',
#     'ror': 'https://ror.org/04pznag94',
#     'display_name': 'Hospital Universitário Clementino Fraga Filho',
#     'country_code': 'BR',
#     'type': 'healthcare',
#     'relationship': 'related'}],
#   'counts_by_year': [{'year': 2025, 'works_count': 23, 'cited_by_count': 3560},
#    {'year': 2024, 'works_count': 6645, 'cited_by_count': 200998},
#    {'year': 2023, 'works_count': 8384, 'cited_by_count': 217980},
#    {'year': 2022, 'works_count': 8330, 'cited_by_count': 206682},
#    {'year': 2021, 'works_count': 9505, 'cited_by_count': 212252},
#    {'year': 2020, 'works_count': 9508, 'cited_by_count': 182727},
#    {'year': 2019, 'works_count': 8035, 'cited_by_count': 147236},
#    {'year': 2018, 'works_count': 7667, 'cited_by_count': 128755},
#    {'year': 2017, 'works_count': 7719, 'cited_by_count': 115957},
#    {'year': 2016, 'works_count': 6722, 'cited_by_count': 108161},
#    {'year': 2015, 'works_count': 7019, 'cited_by_count': 100396},
#    {'year': 2014, 'works_count': 6157, 'cited_by_count': 92934},
#    {'year': 2013, 'works_count': 5936, 'cited_by_count': 83415},
#    {'year': 2012, 'works_count': 5506, 'cited_by_count': 72764}],
#   'roles': [{'role': 'publisher',
#     'id': 'https://openalex.org/P4310312367',
#     'works_count': 19000},
#    {'role': 'institution',
#     'id': 'https://openalex.org/I122140584',
#     'works_count': 144605},
#    {'role': 'funder',
#     'id': 'https://openalex.org/F4320325035',
#     'works_count': 379}],
#   'topics': [{'id': 'https://openalex.org/T12623',
#     'display_name': 'Cultural, Media, and Literary Studies',
#     'count': 3241,
#     'subfield': {'id': 'https://openalex.org/subfields/1211',
#      'display_name': 'Philosophy'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10312',
#     'display_name': 'Health, Nursing, Elderly Care',
#     'count': 2864,
#     'subfield': {'id': 'https://openalex.org/subfields/3600',
#      'display_name': 'General Health Professions'},
#     'field': {'id': 'https://openalex.org/fields/36',
#      'display_name': 'Health Professions'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T11530',
#     'display_name': 'Business and Management Studies',
#     'count': 2601,
#     'subfield': {'id': 'https://openalex.org/subfields/1802',
#      'display_name': 'Information Systems and Management'},
#     'field': {'id': 'https://openalex.org/fields/18',
#      'display_name': 'Decision Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10048',
#     'display_name': 'Particle physics theoretical and experimental studies',
#     'count': 2529,
#     'subfield': {'id': 'https://openalex.org/subfields/3106',
#      'display_name': 'Nuclear and High Energy Physics'},
#     'field': {'id': 'https://openalex.org/fields/31',
#      'display_name': 'Physics and Astronomy'},
#     'domain': {'id': 'https://openalex.org/domains/3',
#      'display_name': 'Physical Sciences'}},
#    {'id': 'https://openalex.org/T10457',
#     'display_name': 'Education Pedagogy and Practices',
#     'count': 2396,
#     'subfield': {'id': 'https://openalex.org/subfields/3304',
#      'display_name': 'Education'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12184',
#     'display_name': 'Linguistics and Education Research',
#     'count': 2342,
#     'subfield': {'id': 'https://openalex.org/subfields/1208',
#      'display_name': 'Literature and Literary Theory'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13179',
#     'display_name': 'Literature, Culture, and Criticism',
#     'count': 2264,
#     'subfield': {'id': 'https://openalex.org/subfields/1208',
#      'display_name': 'Literature and Literary Theory'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13513',
#     'display_name': 'Urban and sociocultural dynamics',
#     'count': 2208,
#     'subfield': {'id': 'https://openalex.org/subfields/3322',
#      'display_name': 'Urban Studies'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12844',
#     'display_name': 'Psychology and Mental Health',
#     'count': 2183,
#     'subfield': {'id': 'https://openalex.org/subfields/3203',
#      'display_name': 'Clinical Psychology'},
#     'field': {'id': 'https://openalex.org/fields/32',
#      'display_name': 'Psychology'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T11858',
#     'display_name': 'Urban Development and Societal Issues',
#     'count': 2157,
#     'subfield': {'id': 'https://openalex.org/subfields/3322',
#      'display_name': 'Urban Studies'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12573',
#     'display_name': 'Education and Digital Technologies',
#     'count': 2108,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10527',
#     'display_name': 'High-Energy Particle Collisions Research',
#     'count': 2021,
#     'subfield': {'id': 'https://openalex.org/subfields/3106',
#      'display_name': 'Nuclear and High Energy Physics'},
#     'field': {'id': 'https://openalex.org/fields/31',
#      'display_name': 'Physics and Astronomy'},
#     'domain': {'id': 'https://openalex.org/domains/3',
#      'display_name': 'Physical Sciences'}},
#    {'id': 'https://openalex.org/T12165',
#     'display_name': 'Environmental Sustainability and Education',
#     'count': 1816,
#     'subfield': {'id': 'https://openalex.org/subfields/2308',
#      'display_name': 'Management, Monitoring, Policy and Law'},
#     'field': {'id': 'https://openalex.org/fields/23',
#      'display_name': 'Environmental Science'},
#     'domain': {'id': 'https://openalex.org/domains/3',
#      'display_name': 'Physical Sciences'}},
#    {'id': 'https://openalex.org/T10890',
#     'display_name': 'Trypanosoma species research and implications',
#     'count': 1695,
#     'subfield': {'id': 'https://openalex.org/subfields/2713',
#      'display_name': 'Epidemiology'},
#     'field': {'id': 'https://openalex.org/fields/27',
#      'display_name': 'Medicine'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T10224',
#     'display_name': 'Quantum Chromodynamics and Particle Interactions',
#     'count': 1695,
#     'subfield': {'id': 'https://openalex.org/subfields/3106',
#      'display_name': 'Nuclear and High Energy Physics'},
#     'field': {'id': 'https://openalex.org/fields/31',
#      'display_name': 'Physics and Astronomy'},
#     'domain': {'id': 'https://openalex.org/domains/3',
#      'display_name': 'Physical Sciences'}},
#    {'id': 'https://openalex.org/T13614',
#     'display_name': 'Social and Economic Solidarity',
#     'count': 1558,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12842',
#     'display_name': 'Youth, Drugs, and Violence',
#     'count': 1511,
#     'subfield': {'id': 'https://openalex.org/subfields/3317',
#      'display_name': 'Demography'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T14376',
#     'display_name': 'Science and Education Research',
#     'count': 1485,
#     'subfield': {'id': 'https://openalex.org/subfields/3304',
#      'display_name': 'Education'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12014',
#     'display_name': 'Fish biology, ecology, and behavior',
#     'count': 1442,
#     'subfield': {'id': 'https://openalex.org/subfields/2309',
#      'display_name': 'Nature and Landscape Conservation'},
#     'field': {'id': 'https://openalex.org/fields/23',
#      'display_name': 'Environmental Science'},
#     'domain': {'id': 'https://openalex.org/domains/3',
#      'display_name': 'Physical Sciences'}},
#    {'id': 'https://openalex.org/T13554',
#     'display_name': 'Brazilian cultural history and politics',
#     'count': 1418,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10823',
#     'display_name': 'Research on Leishmaniasis Studies',
#     'count': 1371,
#     'subfield': {'id': 'https://openalex.org/subfields/2739',
#      'display_name': 'Public Health, Environmental and Occupational Health'},
#     'field': {'id': 'https://openalex.org/fields/27',
#      'display_name': 'Medicine'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T10487',
#     'display_name': 'Plant and animal studies',
#     'count': 1313,
#     'subfield': {'id': 'https://openalex.org/subfields/1105',
#      'display_name': 'Ecology, Evolution, Behavior and Systematics'},
#     'field': {'id': 'https://openalex.org/fields/11',
#      'display_name': 'Agricultural and Biological Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/1',
#      'display_name': 'Life Sciences'}},
#    {'id': 'https://openalex.org/T13564',
#     'display_name': 'Education and Public Policy',
#     'count': 1312,
#     'subfield': {'id': 'https://openalex.org/subfields/3320',
#      'display_name': 'Political Science and International Relations'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13491',
#     'display_name': 'Social and Political Issues',
#     'count': 1215,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13260',
#     'display_name': 'Linguistics and Language Studies',
#     'count': 1209,
#     'subfield': {'id': 'https://openalex.org/subfields/1203',
#      'display_name': 'Language and Linguistics'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}}],
#   'topic_share': [{'id': 'https://openalex.org/T13211',
#     'display_name': 'Memory, Trauma, and Testimony',
#     'value': 0.0241733,
#     'subfield': {'id': 'https://openalex.org/subfields/3205',
#      'display_name': 'Experimental and Cognitive Psychology'},
#     'field': {'id': 'https://openalex.org/fields/32',
#      'display_name': 'Psychology'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13571',
#     'display_name': 'Corporeality, Perception, and Education',
#     'value': 0.0213622,
#     'subfield': {'id': 'https://openalex.org/subfields/1200',
#      'display_name': 'General Arts and Humanities'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12109',
#     'display_name': 'Race, Identity, and Education in Brazil',
#     'value': 0.0206959,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13300',
#     'display_name': 'Contemporary Social and Educational Issues',
#     'value': 0.0206287,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13860',
#     'display_name': 'Arts and Performance Studies',
#     'value': 0.0202569,
#     'subfield': {'id': 'https://openalex.org/subfields/1213',
#      'display_name': 'Visual Arts and Performing Arts'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13513',
#     'display_name': 'Urban and sociocultural dynamics',
#     'value': 0.0201697,
#     'subfield': {'id': 'https://openalex.org/subfields/3322',
#      'display_name': 'Urban Studies'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13662',
#     'display_name': 'Qualitative research in health',
#     'value': 0.0182198,
#     'subfield': {'id': 'https://openalex.org/subfields/3304',
#      'display_name': 'Education'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12988',
#     'display_name': 'Sociology and Education in Brazil',
#     'value': 0.0176948,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T11906',
#     'display_name': 'Gender, Sexuality, and Education',
#     'value': 0.0175228,
#     'subfield': {'id': 'https://openalex.org/subfields/3318',
#      'display_name': 'Gender Studies'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13179',
#     'display_name': 'Literature, Culture, and Criticism',
#     'value': 0.016334,
#     'subfield': {'id': 'https://openalex.org/subfields/1208',
#      'display_name': 'Literature and Literary Theory'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10312',
#     'display_name': 'Health, Nursing, Elderly Care',
#     'value': 0.0158708,
#     'subfield': {'id': 'https://openalex.org/subfields/3600',
#      'display_name': 'General Health Professions'},
#     'field': {'id': 'https://openalex.org/fields/36',
#      'display_name': 'Health Professions'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T13554',
#     'display_name': 'Brazilian cultural history and politics',
#     'value': 0.0157245,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13302',
#     'display_name': 'Amazonian Archaeology and Ethnohistory',
#     'value': 0.0157158,
#     'subfield': {'id': 'https://openalex.org/subfields/1202',
#      'display_name': 'History'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13613',
#     'display_name': 'Health, Education, and Cultural Studies',
#     'value': 0.0152929,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T14038',
#     'display_name': 'Youth, Politics, and Society',
#     'value': 0.0151321,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10890',
#     'display_name': 'Trypanosoma species research and implications',
#     'value': 0.0150994,
#     'subfield': {'id': 'https://openalex.org/subfields/2713',
#      'display_name': 'Epidemiology'},
#     'field': {'id': 'https://openalex.org/fields/27',
#      'display_name': 'Medicine'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T13266',
#     'display_name': 'Indigenous Studies in Latin America',
#     'value': 0.0150754,
#     'subfield': {'id': 'https://openalex.org/subfields/3316',
#      'display_name': 'Cultural Studies'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12623',
#     'display_name': 'Cultural, Media, and Literary Studies',
#     'value': 0.0148541,
#     'subfield': {'id': 'https://openalex.org/subfields/1211',
#      'display_name': 'Philosophy'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T12844',
#     'display_name': 'Psychology and Mental Health',
#     'value': 0.0143217,
#     'subfield': {'id': 'https://openalex.org/subfields/3203',
#      'display_name': 'Clinical Psychology'},
#     'field': {'id': 'https://openalex.org/fields/32',
#      'display_name': 'Psychology'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13822',
#     'display_name': 'Indigenous Health and Education',
#     'value': 0.014291,
#     'subfield': {'id': 'https://openalex.org/subfields/3600',
#      'display_name': 'General Health Professions'},
#     'field': {'id': 'https://openalex.org/fields/36',
#      'display_name': 'Health Professions'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T13296',
#     'display_name': 'Physical Education and Sports Studies',
#     'value': 0.0139935,
#     'subfield': {'id': 'https://openalex.org/subfields/3312',
#      'display_name': 'Sociology and Political Science'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T11858',
#     'display_name': 'Urban Development and Societal Issues',
#     'value': 0.0137457,
#     'subfield': {'id': 'https://openalex.org/subfields/3322',
#      'display_name': 'Urban Studies'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T13260',
#     'display_name': 'Linguistics and Language Studies',
#     'value': 0.0135315,
#     'subfield': {'id': 'https://openalex.org/subfields/1203',
#      'display_name': 'Language and Linguistics'},
#     'field': {'id': 'https://openalex.org/fields/12',
#      'display_name': 'Arts and Humanities'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}},
#    {'id': 'https://openalex.org/T10823',
#     'display_name': 'Research on Leishmaniasis Studies',
#     'value': 0.0132488,
#     'subfield': {'id': 'https://openalex.org/subfields/2739',
#      'display_name': 'Public Health, Environmental and Occupational Health'},
#     'field': {'id': 'https://openalex.org/fields/27',
#      'display_name': 'Medicine'},
#     'domain': {'id': 'https://openalex.org/domains/4',
#      'display_name': 'Health Sciences'}},
#    {'id': 'https://openalex.org/T14487',
#     'display_name': 'Science and Science Education',
#     'value': 0.0127421,
#     'subfield': {'id': 'https://openalex.org/subfields/3320',
#      'display_name': 'Political Science and International Relations'},
#     'field': {'id': 'https://openalex.org/fields/33',
#      'display_name': 'Social Sciences'},
#     'domain': {'id': 'https://openalex.org/domains/2',
#      'display_name': 'Social Sciences'}}],
#   'x_concepts': [{'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 49.9},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 37.8},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 36.3},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 34.1},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 33.6},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 27.6},
#    {'id': 'https://openalex.org/C142362112',
#     'wikidata': 'https://www.wikidata.org/wiki/Q735',
#     'display_name': 'Art',
#     'level': 0,
#     'score': 27.2},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 23.6},
#    {'id': 'https://openalex.org/C15708023',
#     'wikidata': 'https://www.wikidata.org/wiki/Q80083',
#     'display_name': 'Humanities',
#     'level': 1,
#     'score': 22.9},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 22.3},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 22.0},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 21.0},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 20.7}],
#   'is_super_system': False,
#   'works_api_url': 'https://api.openalex.org/works?filter=institutions.id:I122140584',
#   'updated_date': '2025-01-10T14:22:32.208412',
#   'created_date': '2016-06-24'}]

# %%
#That's a lot of information! Let's get only the most important fields for now

def get_relevant_institution_fields(ror):
    data = requests.get(f'https://api.openalex.org/institutions?filter=ror:{ror}').json()
    results = data['results'][0]
    print(f"Institution name: {results['display_name']}")
    print(f"Total works: {results['works_count']}")
    print(f"Works api url: {results['works_api_url']}")

# %%
get_relevant_institution_fields('03490as77')
# Out:
# Institution name: Universidade Federal do Rio de Janeiro
# Total works: 144605
# Works api: https://api.openalex.org/works?filter=institutions.id:I122140584

# %%
#Let's use the works' api url to retrieve first page of works from the institution

data = requests.get(f'https://api.openalex.org/works?filter=institutions.id:I122140584&per-page=1').json()
metadata = data['meta']
metadata
# Out:
# {'count': 142411,
#  'db_response_time_ms': 140,
#  'page': 1,
#  'per_page': 1,
#  'groups_count': None}

# %%
#There are less docs in the 'works' request than in the 'institution' request
#We'll see if searching through ror will get more results
#Searching through raw-affiliation name is not recommended (https://docs.openalex.org/api-entities/works/search-works#why-cant-i-search-by-name-of-related-entity-author-name-institution-name-etc.), but we'll do it anyway

def get_number_of_results(work_api_url):
    return( requests.get(work_api_url).json()['meta']['count'] )

#Using ror
ror_url = 'https://api.openalex.org/works?filter=institutions.ror:03490as77'
print(f'ror: { get_number_of_results(ror_url) }')

raw_affiliation_strings_url = 'https://api.openalex.org/works?filter=raw_affiliation_strings.search:"Universidade Federal do Rio de Janeiro"'
print(f'affiliation_name: { get_number_of_results(ror_url) }')
# Out:
# ror: 142408
# affiliation_name: 142408

# %%
requests.get('https://api.openalex.org/institutions/I122140584').json()['works_count']
# Out:
# 144605

# %%
#Since there is no difference between the methods used to recover data, we'll just check that this happens for other institutions

#https://api.openalex.org/institutions/I122140584

def get_institution_counts(id):
    inst_results = requests.get(f'https://api.openalex.org/institutions/{id}').json()
    work_results = requests.get(f'https://api.openalex.org/works?filter=institutions.id:{id}').json()
    final_results = {
        'Institution name': inst_results['display_name'],
        'Total itens': inst_results['works_count'],
        'Total itens (works api)': work_results['meta']['count']
    }
    print(final_results)
                        
institutions_ids = ['i122140584','i1294671590', 'i27837315', 'i185261750', 'i136199984',
                'i19820366', 'i17974374']
                
for i in institutions_ids:
    get_institution_counts(i)
# Out:
# {'Institution name': 'Universidade Federal do Rio de Janeiro', 'Total itens': 144605, 'Total itens (works api)': 142411}
# {'Institution name': 'Centre National de la Recherche Scientifique', 'Total itens': 1064412, 'Total itens (works api)': 1057182}
# {'Institution name': 'University of Michigan–Ann Arbor', 'Total itens': 925883, 'Total itens (works api)': 921971}
# {'Institution name': 'University of Michigan–Ann Arbor', 'Total itens': 925883, 'Total itens (works api)': 921971}
# {'Institution name': 'University of Toronto', 'Total itens': 489575, 'Total itens (works api)': 487790}
# {'Institution name': 'Harvard University', 'Total itens': 667798, 'Total itens (works api)': 666674}
# {'Institution name': 'Chinese Academy of Sciences', 'Total itens': 836331, 'Total itens (works api)': 835871}
# {'Institution name': 'Universidade de São Paulo', 'Total itens': 403434, 'Total itens (works api)': 400904}

# %%
#So, in general, the number of works returned by the 'works' api is lower than the number listed by the 'institutions' api
#Then, let's use the 'works' api to get all of the UFRJ's publications

##CONTINUAR DAQUI!!!!


url = f'https://api.openalex.org/works?filter=author.ror:I122140584&cursor={}'


# url with a placeholder for cursor
example_url_with_cursor = 'https://api.openalex.org/works?filter=author.id:A5048491430&cursor={}'

cursor = '*'

# loop through pages
while cursor:
    
    # set cursor value and request page from OpenAlex
    url = example_url_with_cursor.format(cursor)
    print("\n" + url)
    page_with_results = requests.get(url).json()
    
    # loop through partial list of results
    results = page_with_results['results']
    for i,work in enumerate(results):
        openalex_id = work['id'].replace("https://openalex.org/", "")
        print(openalex_id, end='\t' if (i+1)%5!=0 else '\n')

    # update cursor to meta.next_cursor
    cursor = page_with_results['meta']['next_cursor']
